# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv= "2017.csv"

# %%
happiness=pd.read_csv(csv)

# %%
happiness.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Afghanistan             141            3.794      3.873661     3.714338
# 1      Albania             109            4.644      4.752464     4.535536
# 2      Algeria              53            5.872      5.978286     5.765714
# 3       Angola             140            3.795      3.951642     3.638358
# 4    Argentina              24            6.599      6.690085     6.507915
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  0.401477  0.581543                  0.180747  0.106180
# 1                  0.996193  0.803685                  0.731160  0.381499
# 2                  1.091864  1.146217                  0.617585  0.233336
# 3                  0.858428  1.104412                  0.049869  0.000000
# 4                  1.185295  1.440451                  0.695137  0.494519
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
happiness_2 = happiness[["Country", "Happiness.Rank", "Economy..GDP.per.Capita.", "Freedom"]]

# %%
happiness_3 = happiness_2.rename(columns={"Country":"country","Happiness.Rank":"happiness_rank",\
                                          "Economy..GDP.per.Capita.":"gdp_per_capita",\
                                         "Freedom":"freedom"})

# %%
happiness_3['country'] = happiness_3['country'].str.replace(" ","")
happiness_3
# Out:
#                     country  happiness_rank  gdp_per_capita   freedom
# 0               Afghanistan             141        0.401477  0.106180
# 1                   Albania             109        0.996193  0.381499
# 2                   Algeria              53        1.091864  0.233336
# 3                    Angola             140        0.858428  0.000000
# 4                 Argentina              24        1.185295  0.494519
# 5                   Armenia             121        0.900597  0.198303
# 6                 Australia              10        1.484415  0.601607
# 7                   Austria              13        1.487097  0.567766
# 8                Azerbaijan              85        1.153602  0.398156
# 9                   Bahrain              41        1.488412  0.536747
# 10               Bangladesh             110        0.586683  0.478357
# 11                  Belarus              67        1.156558  0.295400
# ...

# %%
csv2="directory.csv"

# %%
directory=pd.read_csv(csv2)

# %%
new_directory = directory[directory.Brand == 'Starbucks']

# %%
new_directory2 = new_directory[['Brand','Country']]

# %%
new_directory3=new_directory2.groupby('Country').count()

# %%
cleaned_directory=new_directory3.rename(columns={'Brand':"amount_of_stores"})

# %%
csv3='country_code.csv'

# %%
country_code=pd.read_csv(csv3)

# %%
country_code=country_code.drop(columns=['Unnamed: 0', 'code_3digit'])

# %%
country_code=country_code.rename(columns={"Country_name": "Country"})

# %%
merged_directory=cleaned_directory.merge(country_code, left_on='Country', right_on='code_2digit')

# %%
clean_merged_directory=merged_directory.drop(columns='code_2digit')

# %%
clean_merged_directory=clean_merged_directory[['Country', 'amount_of_stores']]

# %%
clean_merged_directory['Country'] = clean_merged_directory['Country'].str.replace(" ","")

# %%
clean_merged_directory.head()
# Out:
#               Country  amount_of_stores
# 0             Andorra                 1
# 1  UnitedArabEmirates               144
# 2           Argentina               108
# 3             Austria                18
# 4           Australia                22

# %%
exports_csv=clean_merged_directory.to_csv(r'C:\Users\todda\Desktop\SuperDuberProject\clean_merged_directory.csv', index=False)

# %%
csv4='country_profile_variables.csv'

# %%
country_profile = pd.read_csv(csv4)

# %%
country_profile['country'] = country_profile['country'].str.replace(" ","")

# %%
country_profile_small = country_profile[['country', 'Surface area (km2)']]

# %%
country_profile_small=country_profile_small.rename(columns={"country": "a", "Surface area (km2)": "c"})

# %%
rds_connection_string = "postgres:postgres@localhost:5432/SuperUberDuberProject"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# []

# %%
clean_merged_directory.to_sql(name='store_directory',if_exists='append', con=engine, index=False)

# %%
happiness_3.to_sql(name='happiness', con=engine, if_exists='append', index=False)

# %%
country_profile.to_sql(name='country_profile3', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-ef8b30ff35a1> in <module>
# ----> 1 country_profile.to_sql(name='country_profile3', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
pd.read_sql_query('select * from happiness', con=engine).head()
